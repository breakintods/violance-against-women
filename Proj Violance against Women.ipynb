# %%
# get working directory

import os
os.getcwd()
# Out:
# 'C:\\Users\\пк'

# %%
# change directory

os.chdir("C:\\Users\\пк\\Desktop\\jupyter")
os.getcwd()
# Out:
# 'C:\\Users\\пк\\Desktop\\jupyter'

# %%
# upload dataframe

# https://www.kaggle.com/datasets/whenamancodes/violence-against-women-girls

import pandas as pd
df = pd.read_csv('Violence Against Women  Girls Data.csv')

# %%
# explore the data

df.head(20)
# Out:
#     RecordID      Country Gender DemographicsQuestion  \
# 0          1  Afghanistan      F       Marital status
# 1          1  Afghanistan      F            Education
# 2          1  Afghanistan      F            Education
# 3          1  Afghanistan      F            Education
# 4          1  Afghanistan      F       Marital status
# 5          1  Afghanistan      F           Employment
# 6          1  Afghanistan      F                  Age
# 7          1  Afghanistan      F           Employment
# 8          1  Afghanistan      F            Residence
# 9          1  Afghanistan      F                  Age
# 10         1  Afghanistan      F       Marital status
# 11         1  Afghanistan      F            Residence
# 12         1  Afghanistan      F                  Age
# 13         1  Afghanistan      F            Education
# 14         1  Afghanistan      F           Employment
# 15         1  Afghanistan      M       Marital status
# ...

# %%
# remove space in the names of a column

df.columns = df.columns.str.replace(' ', '')

# %%
df.DemographicsResponse.value_counts()
# Out:
# Higher                          840
# Rural                           840
# Unemployed                      840
# 35-49                           840
# 25-34                           840
# Urban                           840
# Secondary                       840
# Primary                         840
# Widowed, divorced, separated    840
# Never married                   840
# 15-24                           840
# Employed for kind               840
# No education                    840
# Employed for cash               840
# Married or living together      840
# Name: DemographicsResponse, dtype: int64

# %%
df.Question.value_counts()
# Out:
# ... if she neglects the children           2100
# ... if she argues with him                 2100
# ... for at least one specific reason       2100
# ... if she goes out without telling him    2100
# ... if she refuses to have sex with him    2100
# ... if she burns the food                  2100
# Name: Question, dtype: int64

# %%
df.groupby('DemographicsQuestion').count()
# Out:
#                       RecordID  Country  Gender  DemographicsResponse  \
# DemographicsQuestion
# Age                       2520     2520    2520                  2520
# Education                 3360     3360    3360                  3360
# Employment                2520     2520    2520                  2520
# Marital status            2520     2520    2520                  2520
# Residence                 1680     1680    1680                  1680
#
#                       Question  SurveyYear  Value
# DemographicsQuestion
# Age                       2520        2520   2274
# Education                 3360        3360   2942
# Employment                2520        2520   2234
# Marital status            2520        2520   2221
# Residence                 1680        1680   1516
